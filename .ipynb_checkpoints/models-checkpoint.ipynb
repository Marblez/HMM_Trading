# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from hmmlearn import hmm

# %%
spy = pd.read_csv('data/SPY_ADV.csv').drop("Unnamed: 0", axis=1).drop(range(2706, 3330))
bookvalue = pd.read_csv('data/BookValue.csv')
momentum = pd.read_csv('data/Momentum.csv')
aqr = pd.read_csv('data/AQR.csv')

# %%
df = momentum.drop(momentum.columns[[2, 3, 4, 5]], axis=1)
df = df.rename(columns={'Returns': 'Momentum'})
df['BookValue'] = bookvalue.iloc[:,1]
df['AQR'] = aqr.iloc[:,1]
length = df.shape[0]

# %%
df.head()
# Out:
#          Date  Momentum  BookValue       AQR
# 0  2007-01-03  0.142173   0.048178 -0.160978
# 1  2007-01-04  0.378864  -0.127376 -1.892236
# 2  2007-01-05 -0.019659   0.009460 -1.166574
# 3  2007-01-08  0.032330   0.198087  0.897662
# 4  2007-01-09 -0.225025  -0.003266 -0.083048

# %%
df.to_csv('data/Factors.csv')

# %%
fig, a =  plt.subplots(2,2)
x = np.arange(1,5)
fig.tight_layout()
a[0][0].plot(range(0,length), df.iloc[:,1])
a[0][0].set_title('Momentum')
a[0][1].plot(range(0,length), df.iloc[:,2])
a[0][1].set_title('BookValue')
a[1][0].plot(range(0,length), df.iloc[:,3])
a[1][0].set_title('AQR')
a[1][1].plot(range(0,length), spy.iloc[:,9])
a[1][1].set_title('SPY')
plt.show()

# %%
returns = df.copy()
returns['SPY'] = spy.iloc[:,9]
for i in range(1, 5):
    returns.iloc[0, i] = 100000

for i in range(1, returns.shape[0]):
    for j in range(1, 5):
        returns.iloc[i, j] = returns.iloc[i-1, j] * (100 + returns.iloc[i,j])/100

# %%
sns.set_style("darkgrid")
plot = plt.figure(figsize=(20,10)) 
plt.plot(returns.iloc[:,1], label="Momentum",)
plt.plot(returns.iloc[:,2], label="Book Value",)
plt.plot(returns.iloc[:,3], label="AQR Multifactor",)
plt.plot(returns.iloc[:,4], label="SPY",)
plot.legend(loc=2, prop={'size': 15})
plt.show()

# %%
# Out:
#             Date       Momentum      BookValue            AQR            SPY
# 0     2007-01-03  100000.000000  100000.000000  100000.000000  100000.000000
# 1     2007-01-04  100378.864429   99872.624363   98107.764393  100212.211226
# 2     2007-01-05  100359.131284   99882.072740   96963.265118   99412.886730
# 3     2007-01-08  100391.577448  100079.926627   97833.667538   99872.679489
# 4     2007-01-09  100165.671151  100076.658172   97752.418415   99787.799384
# ...          ...            ...            ...            ...            ...
# 2701  2017-09-25   82664.676314   91076.807771   41915.320692  176084.036079
# 2702  2017-09-26   82949.279706   91088.416282   41658.166959  176190.146997
# 2703  2017-09-27   83023.205995   91113.603917   41535.180201  176876.290475
# 2704  2017-09-28   82873.514791   91019.799630   41616.561093  177088.501701
# 2705  2017-09-29   82904.953736   90939.928110   41600.690039  177710.974666
#
# [2706 rows x 5 columns]
